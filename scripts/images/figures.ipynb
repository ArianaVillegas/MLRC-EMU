# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

sns.set_style("whitegrid")

# %% [markdown]
# ## EMU QPLEX

# %%
alg_names = [
    'EMU (QPLEX)',
    'EMU (CDS)',
]

maps = [
    '1c3s5z',
    '3s_vs_5z',
    '5m_vs_6m',
    'MMM2',
    '6h_vs_8z',
    '3s5z_vs_3s6z'
]

paths = [
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_1c3s5z_2025-02-04_23-43-08/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_cds_1c3s5z_2025-02-04_23-43-24/1/info.json'
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_3s_vs_5z_2025-02-04_23-52-32/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_cds_3s_vs_5z_2025-02-04_23-52-52/1/info.json'
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_5m_vs_6m_2025-02-04_23-55-04/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_cds_5m_vs_6m_2025-02-05_15-32-22/1/info.json'
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_MMM2_MMM2_2025-02-09_22-14-35/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_MMM2_MMM2_2025-02-09_22-13-50/1/info.json'
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_6h_vs_8z_6h_vs_8z_2025-02-12_17-35-45/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_6h_vs_8z_6h_vs_8z_2025-02-09_22-14-56/1/info.json'
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-09_22-14-16/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-09_22-13-55/1/info.json'
    ]
]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

legend_lines = []
legend_labels = []

for idx, json_paths in enumerate(paths):
    x = []
    y_means = []

    for json_path in json_paths:
        with open(json_path, 'r') as f:
            data = json.load(f)
        x.append(np.array(data["test_battle_won_mean_T"]) / 1e6)
        y_means.append(np.array(data["test_battle_won_mean"]) * 100)

    ax = axes[idx]

    for i in range(len(y_means)):
        line, = ax.plot(x[i], y_means[i], linewidth=2, label=alg_names[i])
        if idx == 0:
            legend_lines.append(line)
            legend_labels.append(alg_names[i])

    ax.set_xlabel("T (mil)")
    ax.set_ylabel("Test Win [%]")
    ax.set_title(maps[idx], fontsize=10)
    ax.set_ylim(0, 100)

    if idx < 3:
        ax.set_xlim(0, 2)
    else:
        ax.set_xlim(0, 5)

fig.legend(legend_lines, legend_labels, loc='upper center', ncol=len(alg_names), fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("plot_comparative_eval.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
alg_names = [
    'EMU (QPLEX)',
    'EMU (QPLEX-No-EI)',
    'EMU (QPLEX-No-SE)',
    'EMC (QPLEX-original)',
]

alg_names_cds = [
    'EMU (CDS)',
    'EMU (CDS-No-EI)',
    'EMU (CDS-No-SE)',
    'CDS (QPLEX-original)',
]

maps = [
    '6h_vs_8z',
    '3s5z_vs_3s6z'
]

maps_cds = ['3s5z_vs_3s6z']

paths = [
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_6h_vs_8z_6h_vs_8z_2025-02-12_17-35-45/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_6h_vs_8z_6h_vs_8z_2025-02-16_00-27-06/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_6h_vs_8z_6h_vs_8z_2025-02-16_00-29-10/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_6h_vs_8z_6h_vs_8z_2025-02-16_00-18-43/1/info.json',
    ],
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-09_22-14-16/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_00-27-06/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_00-29-10/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_00-18-43/1/info.json'
    ]
]

paths_cds = [
    [
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-09_22-13-55/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_01-03-54/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_00-40-01/1/info.json',
        '/home/diego.quispe/emu_dev/MLRC-EMU/src/EMU_release_pymarl/results/sacred/EMU_sc2_hard_cds_3s5z_vs_3s6z_3s5z_vs_3s6z_2025-02-16_00-35-12/1/info.json'
    ]
]


fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes = axes.flatten()

for idx, json_paths in enumerate(paths):
    x, y_means = [], []
    for json_path in json_paths:
        with open(json_path, 'r') as f:
            data = json.load(f)
        x.append(np.array(data["test_battle_won_mean_T"]) / 1e6)
        y_means.append(np.array(data["test_battle_won_mean"]) * 100)

    ax = axes[idx]
    for i in range(len(y_means)):
        ax.plot(x[i], y_means[i], linewidth=2, label=alg_names[i])
    ax.set_xlabel("T (mil)")
    ax.set_ylabel("Test Win [%]")
    ax.set_title(maps[idx], fontsize=10)
    ax.set_ylim(0, 100)
    ax.set_xlim(0, 4)
    ax.legend(bbox_to_anchor=(0.5, -0.2), loc='upper center',
             ncol=2, fontsize=8, frameon=True,
             fancybox=True)

for idx, json_paths in enumerate(paths_cds):
    x, y_means = [], []
    for json_path in json_paths:
        with open(json_path, 'r') as f:
            data = json.load(f)
        x.append(np.array(data["test_battle_won_mean_T"]) / 1e6)
        y_means.append(np.array(data["test_battle_won_mean"]) * 100)

    ax = axes[2]
    for i in range(len(y_means)):
        ax.plot(x[i], y_means[i], linewidth=2, label=alg_names_cds[i])
    ax.set_xlabel("T (mil)")
    ax.set_ylabel("Test Win [%]")
    ax.set_title(maps_cds[idx], fontsize=10)
    ax.set_ylim(0, 100)
    ax.set_xlim(0, 4)
    ax.legend(bbox_to_anchor=(0.5, -0.2), loc='upper center',
             ncol=2, fontsize=8, frameon=True,
             fancybox=True)



plt.tight_layout()
plt.savefig("plot_further_ablation.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
alg_names = [
    'EMU (QPLEX)',
    'EMU (CDS)',
]

maps = [
    '3_vs_1WK',
    'CA_easy',
    'CA_hard'
]

paths = [
    [
        '/home/diego.quispe/gf_khipu_results/last_bind/sacred/EMU_grf_academy_3_vs_1_with_keeper_2025-02-17_00-59-24/1/info.json',
        '/home/diego.quispe/gf_khipu_results/last_bind/sacred/EMU_grf_cds_academy_3_vs_1_with_keeper_2025-02-17_00-59-24/1/info.json'
    ],
    [
        '/home/diego.quispe/gf_khipu_results/results_bind/sacred/EMU_grf_academy_counterattack_easy_2025-02-12_23-22-28/1/info.json',
        '/home/diego.quispe/gf_khipu_results/last_bind/sacred/EMU_grf_cds_academy_counterattack_easy_2025-02-17_01-01-47/1/info.json'
    ],
    [
        '/home/diego.quispe/gf_khipu_results/results_bind/sacred/EMU_grf_academy_counterattack_hard_2025-02-17_01-03-04/1/info.json',
        '/home/diego.quispe/gf_khipu_results/results_bind/sacred/EMU_grf_cds_academy_counterattack_hard_2025-02-12_23-22-22/1/info.json'
    ],
]


fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes = axes.flatten()

legend_lines = []
legend_labels = []

for idx, json_paths in enumerate(paths):

    x = []
    y_means = []

    for json_path in json_paths:
        with open(json_path, 'r') as f:
            data = json.load(f)
        x.append(np.array(data["test_score_reward_mean_T"]) / 1e6)
        y_means.append(np.array(data["test_score_reward_mean"]) * 100)

    ax = axes[idx]

    for i in range(len(y_means)):
        line, = ax.plot(x[i], y_means[i], linewidth=2, label=alg_names[i])
        if idx == 0:  # Solo agregar una vez para evitar repeticiones en la leyenda
            legend_lines.append(line)
            legend_labels.append(alg_names[i])

    ax.set_xlabel("T (mil)")
    ax.set_ylabel("Test Win [%]")
    ax.set_title(maps[idx], fontsize=10)
    if idx == 2:
        ax.set_xlim(0, 1.8)
    else:
        ax.set_xlim(0, 2)
    ax.set_ylim(0, 100)

fig.legend(legend_lines, legend_labels, loc='upper center', ncol=len(alg_names), fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.savefig("plot_comparative_eval_gf.png", dpi=300, bbox_inches='tight')
plt.show()
